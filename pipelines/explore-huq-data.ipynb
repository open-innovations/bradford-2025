# %%
import petl as etl
from utils.paths import HUQ
from datetime import datetime
from statistics import mean

# %%
# Read the CSV
footfall = etl.fromcsv(HUQ / "footfall.csv")
# Convert estimated footfall into an integer, then remove rows where estimated footfall is none
footfall = etl.convert(footfall, 'estimated_actual_footfall', int).selectnotnone('estimated_actual_footfall')
# Separate the datestamp into columns for each part
footfall = etl.addfield(footfall, 'month', lambda rec: datetime.fromisoformat(rec['datestamp']).date().month)
footfall = etl.addfield(footfall, 'year', lambda rec: datetime.fromisoformat(rec['datestamp']).date().year)
footfall = etl.addfield(footfall, 'day', lambda rec: datetime.fromisoformat(rec['datestamp']).date().day)
footfall = etl.addfield(footfall, 'day_of_week', lambda rec: datetime.fromisoformat(rec['datestamp']).strftime("%w"))
footfall = etl.addfield(footfall, 'day_name', lambda rec: datetime.fromisoformat(rec['datestamp']).strftime("%A"))
# footfall = etl.addfield(footfall, 'day_name', lambda rec: datetime.fromisoformat(rec['datestamp']).strftime("%A"))

# %% [markdown]
# Create an baseline per location per day, using data for years 2019, 2023, 2024.

# %%
# Select years
baseline_years = etl.selectin(footfall, 'year', [2019, 2023, 2024])

# Create a baseline by date
baseline_by_date = etl.aggregate(table=baseline_years, key=['centre_name', 'month', 'day'], aggregation=mean, value='estimated_actual_footfall').rename('value', 'baseline')
baseline_by_date
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/IPython/core/formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/IPython/lib/pretty.py:411, in RepresentationPrinter.pretty(self, obj)
#     400                         return meth(obj, self, cycle)
#     401                 if (
#     402                     cls is not object
#     403                     # check if cls defines __repr__
#    (...)    409                     and callable(_safe_getattr(cls, "__repr__", None))
#     410                 ):
# --> 411                     return _repr_pprint(obj, self, cycle)
#     413     return _default_pprint(obj, self, cycle)
#     414 finally:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/IPython/lib/pretty.py:786, in _repr_pprint(obj, p, cycle)
#     784 """A pprint that just redirects to the normal repr function."""
#     785 # Find newlines and replace them with p.break_()
# --> 786 output = repr(obj)
#     787 lines = output.splitlines()
#     788 with p.group():
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:135, in _table_repr(table)
#     134 def _table_repr(table):
# --> 135     return str(look(table))
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:104, in Look.__repr__(self)
#     101 def __repr__(self):
#     102
#     103     # determine if table overflows limit
# --> 104     table, overflow = _vis_overflow(self.table, self.limit)
#     106     # construct output
#     107     style = self.style
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:540, in _vis_overflow(table, limit)
#     537 overflow = False
#     538 if limit:
#     539     # try reading one more than the limit, to see if there are more rows
# --> 540     table = list(islice(table, 0, limit+2))
#     541     if len(table) > limit+1:
#     542         overflow = True
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/headers.py:99, in iterrename(source, spec, strict)
#      94 outhdr = [spec[i] if i in spec
#      95           else spec[f] if f in spec
#      96           else f
#      97           for i, f in enumerate(flds)]
#      98 yield tuple(outhdr)
# ---> 99 for row in it:
#     100     yield tuple(row)
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/reductions.py:280, in itersimpleaggregate(table, key, aggregation, value, field)
#     278 # generate data
#     279 if isinstance(key, (list, tuple)):
# --> 280     for k, grp in rowgroupby(table, key, value):
#     281         yield tuple(k) + (aggregation(grp),)
#     282 elif key is None:
#     283     # special case counting
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/base.py:711, in rowgroupby(table, key, value)
#     709 it = iter(table)
#     710 try:
# --> 711     hdr = next(it)
#     712 except StopIteration:
#     713     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/sorts.py:290, in SortView._iternocache(self, source, key, reverse)
#     287 it = iter(source)
#     289 try:
# --> 290     hdr = next(it)
#     291 except StopIteration:
#     292     if key is None:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/selects.py:116, in iterfieldselect(source, field, where, complement, missing)
#     114 it = iter(source)
#     115 try:
# --> 116     hdr = next(it)
#     117     yield tuple(hdr)
#     118 except StopIteration:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
#     [... skipping similar frames: iteraddfield at line 546 (2 times), iterstack at line 468 (2 times)]
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/selects.py:116, in iterfieldselect(source, field, where, complement, missing)
#     114 it = iter(source)
#     115 try:
# --> 116     hdr = next(it)
#     117     yield tuple(hdr)
#     118 except StopIteration:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/conversions.py:358, in iterfieldconvert(source, converters, failonerror, errorvalue, where, pass_row)
#     356 it = iter(source)
#     357 try:
# --> 358     hdr = next(it)
#     359     flds = list(map(text_type, hdr))
#     360     yield tuple(hdr)  # these are not modified
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/io/csv_py3.py:32, in CSVView.__iter__(self)
#      30 if self.header is not None:
#      31     yield tuple(self.header)
# ---> 32 with self.source.open('rb') as buf:
#      33     csvfile = io.TextIOWrapper(buf, encoding=self.encoding,
#      34                                errors=self.errors, newline='')
#      35     try:
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lukestrangetdc/GitHub/oi/bradford-2025/data/huq/footfall.csv'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:561, in _display_html(table, limit, vrepr, index_header, caption, tr_style, td_styles, encoding, truncate, epilogue)
#     558 if encoding is None:
#     559     encoding = locale.getpreferredencoding()
# --> 561 table, overflow = _vis_overflow(table, limit)
#     562 buf = MemorySource()
#     563 tohtml(table, buf, encoding=encoding, index_header=index_header,
#     564        vrepr=vrepr, caption=caption, tr_style=tr_style,
#     565        td_styles=td_styles, truncate=truncate)
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:540, in _vis_overflow(table, limit)
#     537 overflow = False
#     538 if limit:
#     539     # try reading one more than the limit, to see if there are more rows
# --> 540     table = list(islice(table, 0, limit+2))
#     541     if len(table) > limit+1:
#     542         overflow = True
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/headers.py:99, in iterrename(source, spec, strict)
#      94 outhdr = [spec[i] if i in spec
#      95           else spec[f] if f in spec
#      96           else f
#      97           for i, f in enumerate(flds)]
#      98 yield tuple(outhdr)
# ---> 99 for row in it:
#     100     yield tuple(row)
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/reductions.py:280, in itersimpleaggregate(table, key, aggregation, value, field)
#     278 # generate data
#     279 if isinstance(key, (list, tuple)):
# --> 280     for k, grp in rowgroupby(table, key, value):
#     281         yield tuple(k) + (aggregation(grp),)
#     282 elif key is None:
#     283     # special case counting
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/base.py:711, in rowgroupby(table, key, value)
#     709 it = iter(table)
#     710 try:
# --> 711     hdr = next(it)
#     712 except StopIteration:
#     713     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/sorts.py:290, in SortView._iternocache(self, source, key, reverse)
#     287 it = iter(source)
#     289 try:
# --> 290     hdr = next(it)
#     291 except StopIteration:
#     292     if key is None:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/selects.py:116, in iterfieldselect(source, field, where, complement, missing)
#     114 it = iter(source)
#     115 try:
# --> 116     hdr = next(it)
#     117     yield tuple(hdr)
#     118 except StopIteration:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
#     [... skipping similar frames: iteraddfield at line 546 (2 times), iterstack at line 468 (2 times)]
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/selects.py:116, in iterfieldselect(source, field, where, complement, missing)
#     114 it = iter(source)
#     115 try:
# --> 116     hdr = next(it)
#     117     yield tuple(hdr)
#     118 except StopIteration:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/conversions.py:358, in iterfieldconvert(source, converters, failonerror, errorvalue, where, pass_row)
#     356 it = iter(source)
#     357 try:
# --> 358     hdr = next(it)
#     359     flds = list(map(text_type, hdr))
#     360     yield tuple(hdr)  # these are not modified
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/io/csv_py3.py:32, in CSVView.__iter__(self)
#      30 if self.header is not None:
#      31     yield tuple(self.header)
# ---> 32 with self.source.open('rb') as buf:
#      33     csvfile = io.TextIOWrapper(buf, encoding=self.encoding,
#      34                                errors=self.errors, newline='')
#      35     try:
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lukestrangetdc/GitHub/oi/bradford-2025/data/huq/footfall.csv'

# %%
# 2025 values
values_2025 = etl.select(footfall, lambda r: r['year'] == 2025).cut(['centre_name', 'month', 'day', 'estimated_actual_footfall']).rename('estimated_actual_footfall', '2025')
values_2025
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/IPython/core/formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/IPython/lib/pretty.py:411, in RepresentationPrinter.pretty(self, obj)
#     400                         return meth(obj, self, cycle)
#     401                 if (
#     402                     cls is not object
#     403                     # check if cls defines __repr__
#    (...)    409                     and callable(_safe_getattr(cls, "__repr__", None))
#     410                 ):
# --> 411                     return _repr_pprint(obj, self, cycle)
#     413     return _default_pprint(obj, self, cycle)
#     414 finally:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/IPython/lib/pretty.py:786, in _repr_pprint(obj, p, cycle)
#     784 """A pprint that just redirects to the normal repr function."""
#     785 # Find newlines and replace them with p.break_()
# --> 786 output = repr(obj)
#     787 lines = output.splitlines()
#     788 with p.group():
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:135, in _table_repr(table)
#     134 def _table_repr(table):
# --> 135     return str(look(table))
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:104, in Look.__repr__(self)
#     101 def __repr__(self):
#     102
#     103     # determine if table overflows limit
# --> 104     table, overflow = _vis_overflow(self.table, self.limit)
#     106     # construct output
#     107     style = self.style
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:540, in _vis_overflow(table, limit)
#     537 overflow = False
#     538 if limit:
#     539     # try reading one more than the limit, to see if there are more rows
# --> 540     table = list(islice(table, 0, limit+2))
#     541     if len(table) > limit+1:
#     542         overflow = True
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/headers.py:83, in iterrename(source, spec, strict)
#      81 it = iter(source)
#      82 try:
# ---> 83     hdr = next(it)
#      84 except StopIteration:
#      85     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:134, in itercut(source, spec, missing)
#     132 # convert field selection into field indices
#     133 try:
# --> 134     hdr = next(it)
#     135 except StopIteration:
#     136     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/selects.py:134, in iterrowselect(source, where, missing, complement)
#     132 it = iter(source)
#     133 try:
# --> 134     hdr = next(it)
#     135 except StopIteration:
#     136     return  # will yield nothing
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
#     [... skipping similar frames: iteraddfield at line 546 (2 times), iterstack at line 468 (2 times)]
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/selects.py:116, in iterfieldselect(source, field, where, complement, missing)
#     114 it = iter(source)
#     115 try:
# --> 116     hdr = next(it)
#     117     yield tuple(hdr)
#     118 except StopIteration:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/conversions.py:358, in iterfieldconvert(source, converters, failonerror, errorvalue, where, pass_row)
#     356 it = iter(source)
#     357 try:
# --> 358     hdr = next(it)
#     359     flds = list(map(text_type, hdr))
#     360     yield tuple(hdr)  # these are not modified
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/io/csv_py3.py:32, in CSVView.__iter__(self)
#      30 if self.header is not None:
#      31     yield tuple(self.header)
# ---> 32 with self.source.open('rb') as buf:
#      33     csvfile = io.TextIOWrapper(buf, encoding=self.encoding,
#      34                                errors=self.errors, newline='')
#      35     try:
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lukestrangetdc/GitHub/oi/bradford-2025/data/huq/footfall.csv'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:561, in _display_html(table, limit, vrepr, index_header, caption, tr_style, td_styles, encoding, truncate, epilogue)
#     558 if encoding is None:
#     559     encoding = locale.getpreferredencoding()
# --> 561 table, overflow = _vis_overflow(table, limit)
#     562 buf = MemorySource()
#     563 tohtml(table, buf, encoding=encoding, index_header=index_header,
#     564        vrepr=vrepr, caption=caption, tr_style=tr_style,
#     565        td_styles=td_styles, truncate=truncate)
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/util/vis.py:540, in _vis_overflow(table, limit)
#     537 overflow = False
#     538 if limit:
#     539     # try reading one more than the limit, to see if there are more rows
# --> 540     table = list(islice(table, 0, limit+2))
#     541     if len(table) > limit+1:
#     542         overflow = True
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/headers.py:83, in iterrename(source, spec, strict)
#      81 it = iter(source)
#      82 try:
# ---> 83     hdr = next(it)
#      84 except StopIteration:
#      85     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:134, in itercut(source, spec, missing)
#     132 # convert field selection into field indices
#     133 try:
# --> 134     hdr = next(it)
#     135 except StopIteration:
#     136     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/selects.py:134, in iterrowselect(source, where, missing, complement)
#     132 it = iter(source)
#     133 try:
# --> 134     hdr = next(it)
#     135 except StopIteration:
#     136     return  # will yield nothing
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
#     [... skipping similar frames: iteraddfield at line 546 (2 times), iterstack at line 468 (2 times)]
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:546, in iteraddfield(source, field, value, index)
#     544 it = iter(source)
#     545 try:
# --> 546     hdr = next(it)
#     547 except StopIteration:
#     548     hdr = []
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/basics.py:468, in iterstack(sources, missing, trim, pad)
#     466 for it in its:
#     467     try:
# --> 468         hdrs.append(next(it))
#     469     except StopIteration:
#     470         hdrs.append([])
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/selects.py:116, in iterfieldselect(source, field, where, complement, missing)
#     114 it = iter(source)
#     115 try:
# --> 116     hdr = next(it)
#     117     yield tuple(hdr)
#     118 except StopIteration:
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/transform/conversions.py:358, in iterfieldconvert(source, converters, failonerror, errorvalue, where, pass_row)
#     356 it = iter(source)
#     357 try:
# --> 358     hdr = next(it)
#     359     flds = list(map(text_type, hdr))
#     360     yield tuple(hdr)  # these are not modified
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/io/csv_py3.py:32, in CSVView.__iter__(self)
#      30 if self.header is not None:
#      31     yield tuple(self.header)
# ---> 32 with self.source.open('rb') as buf:
#      33     csvfile = io.TextIOWrapper(buf, encoding=self.encoding,
#      34                                errors=self.errors, newline='')
#      35     try:
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lukestrangetdc/GitHub/oi/bradford-2025/data/huq/footfall.csv'

# %%
# Join the baseline and 2025 into one table and perform some simple transforms for formatting etc.
summary =  ( etl.leftjoin(left=baseline_by_date, right=values_2025, key=['centre_name', 'month', 'day'])
            .addfield('datestamp', lambda row: '2025-' + str(row['month']).zfill(2) + '-' + str(row['day']).zfill(2))
            .cutout('month', 'day')
            .sort(('datestamp', 'centre_name'), reverse=False)
            .cut('datestamp', 'centre_name', '2025', 'baseline')
            .convert('baseline', round)
            # .select(lambda r: r.centre_name == 'Met Office - Bradford')
        )

etl.tocsv(summary, HUQ / 'footfall_2025_vs_baseline_by_centre_name_by_date.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 11
#       1 # Join the baseline and 2025 into one table and perform some simple transforms for formatting etc.
#       2 summary =  ( etl.leftjoin(left=baseline_by_date, right=values_2025, key=['centre_name', 'month', 'day'])
#       3             .addfield('datestamp', lambda row: '2025-' + str(row['month']).zfill(2) + '-' + str(row['day']).zfill(2))
#       4             .cutout('month', 'day')
#    (...)      8             # .select(lambda r: r.centre_name == 'Met Office - Bradford')
#       9         )
# ---> 11 etl.tocsv(summary, HUQ / 'footfall_2025_vs_baseline_by_centre_name_by_date.csv')
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/io/csv.py:108, in tocsv(table, source, encoding, errors, write_header, **csvargs)
#     106 source = write_source_from_arg(source)
#     107 csvargs.setdefault('dialect', 'excel')
# --> 108 tocsv_impl(table, source=source, encoding=encoding, errors=errors,
#     109            write_header=write_header, **csvargs)
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/io/csv_py3.py:44, in tocsv_impl(table, source, **kwargs)
#      43 def tocsv_impl(table, source, **kwargs):
# ---> 44     _writecsv(table, source=source, mode='wb', **kwargs)
#
# File ~/.local/share/virtualenvs/bradford-2025-d7fzOpeT/lib/python3.12/site-packages/petl/io/csv_py3.py:53, in _writecsv(table, source, mode, write_header, encoding, errors, **csvargs)
#      51 def _writecsv(table, source, mode, write_header, encoding, errors, **csvargs):
#      52     rows = table if write_header else data(table)
# ---> 53     with source.open(mode) as buf:
#      54         # wrap buffer for text IO
#      55         csvfile = io.TextIOWrapper(buf, encoding=encoding, errors=errors,
#      56                                    newline='')
#      57         try:
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lukestrangetdc/GitHub/oi/bradford-2025/data/huq/footfall_2025_vs_baseline_by_centre_name_by_date.csv'

# %% [markdown]
# # TODO
#
# We also want to look at comparing years by correcting for day of the week, rather than using dates (as above). This should give a fairer comparison because weekends (primarily) have different footfall.
#
# To do this,
# - For each year, find first of Jan. Work out what day of week it is. (1-7).
# - 2025 starts on Weds (3).
# - 2024 starts Monday (1), so we need to shift all 2024 dates back by 2 days (so that the first Wednesday of 2024 lines up with the first day (Wednesday of 2025)).
# - We'd add a 'day of year' column to align the days together.
